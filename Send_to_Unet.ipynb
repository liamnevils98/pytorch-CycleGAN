# %%
from PIL import Image
import os
import numpy as np

# %%
name_list=[]
for name in os.listdir("/lfs/Nevils/CGAN/art_noise/test_latest/images"):
    if name.endswith("fake_B.png"):
        name_list.append(name)

# %%
for name in name_list:
    img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/"+name))[:,:,0]
    img=Image.fromarray(img)
    name=name.strip("_fake_B.png")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/images/"+name)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r010_c000.png")
# Out:
# 1000
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7FF74C29BBE0>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r010_c000.png"))
# Out:
# array([[107, 109, 107, ..., 110, 112, 105],
#        [109, 109, 110, ..., 111, 107,  98],
#        [108, 109, 108, ..., 112, 108,  97],
#        ...,
#        [ 94,  95,  95, ..., 110, 106, 111],
#        [ 95,  95,  96, ..., 110, 109, 111],
#        [ 93,  95,  97, ..., 110, 111, 109]], dtype=uint8)

# %%
label_list=[]
for label in os.listdir("/data/Ro_ImageData/32xOTSU"):
    label=label.strip(".tiff")+".png"
    if label in os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images"):
        label_list.append(label)

# %%
for label in label_list:
    label=label.strip(".png")+".tiff"
    img=Image.open("/data/Ro_ImageData/32xOTSU/"+label)
    img=img.resize((256,256,))
    label=label.strip(".tiff")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/masks/0/"+label)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/masks/0")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r010_c000.png")
# Out:
# 1000
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256 at 0x7FF764C9D040>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r010_c000.png"))
# Out:
# array([[  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255,   0,   0],
#        [  0,   0,   0, ..., 255, 255,   0],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]], dtype=uint8)
