# %%
from PIL import Image
import os
import numpy as np

# %%
name_list=[]
for name in os.listdir("/lfs/Nevils/CGAN/art_noise/test_latest/images"):
    if name.endswith("fake_B.png"):
        name_list.append(name)

# %%
for name in name_list:
    img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/"+name))[:,:,0]
    img=Image.fromarray(img)
    name=name.strip("_fake_B.png")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/images/"+name)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r012_c020.png")
# Out:
# 1000
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F25C86FEB20>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r012_c020.png"))
# Out:
# array([[109, 109, 108, ..., 112, 109, 109],
#        [109, 110, 110, ..., 107, 110, 111],
#        [109, 109, 108, ..., 109, 110, 112],
#        ...,
#        [108, 109, 108, ...,  91,  90,  93],
#        [109, 109, 108, ...,  91,  90,  90],
#        [108, 107, 108, ...,  91,  92,  90]], dtype=uint8)

# %%
label_list=[]
for label in os.listdir("/data/Ro_ImageData/32xOTSU/"):
    label=label.strip(".tiff")+".png"
    if label in os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images"):
        label_list.append(label)

# %%
for label in label_list:
    label=label.strip(".png")+".tiff"
    img=Image.open("/data/Ro_ImageData/32xOTSU/"+label)
    img=img.resize((256,256,))
    label=label.strip(".tiff")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/masks/0/"+label)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/masks/0")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r012_c020.png")
# Out:
# 1000
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256 at 0x7F25AC329E80>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r012_c020.png"))
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0]], dtype=uint8)
