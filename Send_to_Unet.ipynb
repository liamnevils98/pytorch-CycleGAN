# %%
from PIL import Image
import os
import numpy as np

# %%
name_list=[]
for name in os.listdir("/lfs/Nevils/CGAN/art_noise/test_latest/images"):
    if name.endswith("fake_B.png"):
        name_list.append(name)

# %%
for name in name_list:
    img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/"+name))[:,:,0]
    img=Image.fromarray(img)
    name=name.strip("_fake_B.png")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/images/"+name)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r012_c020_8.png")
# Out:
# 16000
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F25AC32A760>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/images/Tile_r012_c020_8.png"))
# Out:
# array([[107, 100, 118, ..., 109, 111, 109],
#        [105, 105, 128, ..., 119, 116, 110],
#        [104, 104, 110, ..., 108, 112, 110],
#        ...,
#        [104, 106, 115, ..., 104,  99,  98],
#        [109, 103, 108, ..., 102, 110, 108],
#        [112, 101, 105, ..., 109, 104, 104]], dtype=uint8)

# %%
label_list=[]
for label in os.listdir("/lfs/Nevils/files_256/masks"):
    label=label.strip(".tiff")+".png"
    if label in os.listdir("/lfs/Nevils/Unet/inputs/art_noise/images"):
        label_list.append(label)

# %%
for label in label_list:
    label=label.strip(".png")+".tiff"
    img=Image.open("/lfs/Nevils/files_256/masks/"+label)
    #img=img.resize((256,256,))
    label=label.strip(".tiff")+".png"
    img.save("/lfs/Nevils/Unet/inputs/art_noise/masks/0/"+label)

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise/masks/0")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r012_c020_8.png")
# Out:
# 16000
# <PIL.PngImagePlugin.PngImageFile image mode=P size=255x255 at 0x7F25C8674370>

# %%
np.asarray(Image.open("/lfs/Nevils/Unet/inputs/art_noise/masks/0/Tile_r012_c020_8.png"))
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
