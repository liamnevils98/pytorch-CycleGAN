# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp
from PIL import Image
######################
#Check outputs aren't messed up in here

# %%
Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r010_c002_real_A.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FF229911E80>

# %%
img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r010_c001_real_A.png"))[:,:,0]
img=img.reshape(1,np.shape(img)[0]**2)
img=img[0,:]
plt.hist(img,bins=100, density=False, facecolor="b")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r010_c001_real_B.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FF223AF7FD0>

# %%
img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r010_c001_real_B.png"))[:,:,0]
img=img.reshape(1,np.shape(img)[0]**2)
img=img[0,:]
plt.hist(img,bins=100, density=False, facecolor="g")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r012_c020_fake_A.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FF223BECDF0>

# %%
img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r012_c020_fake_A.png"))[:,:,0]
img=img.reshape(1,np.shape(img)[0]**2)
img=img[0,:]
plt.hist(img,bins=100, density=False, facecolor="b")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r010_c002_fake_B.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FF223CEC6D0>

# %%
img=np.asarray(Image.open("/lfs/Nevils/CGAN/art_noise/test_latest/images/Tile_r012_c020_fake_B.png"))[:,:,0]
img=img.reshape(1,np.shape(img)[0]**2)
img=img[0,:]
plt.hist(img,bins=100, density=False, facecolor="g")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
