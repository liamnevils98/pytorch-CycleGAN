# %%
from PIL import Image
import os
import numpy as np

# %%
for name in os.listdir("/data/Ro_ImageData/trainA"):
    if name.endswith(".tiff"):
        img=Image.open("/data/Ro_ImageData/trainA/"+name)

        img1=img.crop((0,0,255,255))
        img1.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_1.tiff")
        img1.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_1.tiff")

        img2=img.crop((256,0,511,255))
        img2.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_2.tiff")
        img2.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_2.tiff")

        img3=img.crop((512,0,767,255))
        img3.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_3.tiff")
        img3.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_3.tiff")

        img4=img.crop((768,0,1023,255))
        img4.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_4.tiff")
        img4.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_4.tiff")



        img5=img.crop((0,256,255,511))
        img5.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_5.tiff")
        img5.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_5.tiff")

        img6=img.crop((256,256,511,511))
        img6.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_6.tiff")
        img6.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_6.tiff")

        img7=img.crop((512,256,767,511))
        img7.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_7.tiff")
        img7.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_7.tiff")

        img8=img.crop((768,256,1023,511))
        img8.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_8.tiff")
        img8.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_8.tiff")


        img9=img.crop((0,512,255,767))
        img9.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_9.tiff")
        img9.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_9.tiff")

        img10=img.crop((256,512,511,767))
        img10.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_10.tiff")
        img10.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_10.tiff")

        img11=img.crop((512,512,767,767))
        img11.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_11.tiff")
        img11.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_11.tiff")

        img12=img.crop((768,512,1023,767))
        img12.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_12.tiff")
        img12.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_12.tiff")



        img13=img.crop((0,768,255,1023))
        img13.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_13.tiff")
        img13.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_13.tiff")

        img14=img.crop((256,768,511,1023))
        img14.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_14.tiff")
        img14.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_14.tiff")

        img15=img.crop((512,768,767,1023))
        img15.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_15.tiff")
        img15.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_15.tiff")

        img16=img.crop((768,768,1023,1023))
        img16.save("/lfs/Nevils/files_256/trainA/"+name.strip(".tiff")+"_16.tiff")
        img16.save("/lfs/Nevils/files_256/testA/"+name.strip(".tiff")+"_16.tiff")

# %%
for name in os.listdir("/data/Ro_ImageData/trainB"):
    if name.endswith(".tiff"):
        img=Image.open("/data/Ro_ImageData/trainB/"+name)

        img1=img.crop((0,0,255,255))
        img1.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_1.tiff")
        img1.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_1.tiff")

        img2=img.crop((256,0,511,255))
        img2.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_2.tiff")
        img2.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_2.tiff")

        img3=img.crop((512,0,767,255))
        img3.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_3.tiff")
        img3.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_3.tiff")

        img4=img.crop((768,0,1023,255))
        img4.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_4.tiff")
        img4.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_4.tiff")



        img5=img.crop((0,256,255,511))
        img5.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_5.tiff")
        img5.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_5.tiff")

        img6=img.crop((256,256,511,511))
        img6.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_6.tiff")
        img6.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_6.tiff")

        img7=img.crop((512,256,767,511))
        img7.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_7.tiff")
        img7.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_7.tiff")

        img8=img.crop((768,256,1023,511))
        img8.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_8.tiff")
        img8.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_8.tiff")


        img9=img.crop((0,512,255,767))
        img9.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_9.tiff")
        img9.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_9.tiff")

        img10=img.crop((256,512,511,767))
        img10.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_10.tiff")
        img10.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_10.tiff")

        img11=img.crop((512,512,767,767))
        img11.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_11.tiff")
        img11.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_11.tiff")

        img12=img.crop((768,512,1023,767))
        img12.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_12.tiff")
        img12.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_12.tiff")



        img13=img.crop((0,768,255,1023))
        img13.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_13.tiff")
        img13.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_13.tiff")

        img14=img.crop((256,768,511,1023))
        img14.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_14.tiff")
        img14.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_14.tiff")

        img15=img.crop((512,768,767,1023))
        img15.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_15.tiff")
        img15.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_15.tiff")

        img16=img.crop((768,768,1023,1023))
        img16.save("/lfs/Nevils/files_256/trainB/"+name.strip(".tiff")+"_16.tiff")
        img16.save("/lfs/Nevils/files_256/testB/"+name.strip(".tiff")+"_16.tiff")

# %%
for name in os.listdir("/data/Ro_ImageData/32xOTSU"):
    if name.endswith(".tiff"):
        img=Image.open("/data/Ro_ImageData/32xOTSU/"+name)

        img1=img.crop((0,0,255,255))
        img1.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_1.tiff")

        img2=img.crop((256,0,511,255))
        img2.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_2.tiff")

        img3=img.crop((512,0,767,255))
        img3.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_3.tiff")

        img4=img.crop((768,0,1023,255))
        img4.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_4.tiff")



        img5=img.crop((0,256,255,511))
        img5.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_5.tiff")

        img6=img.crop((256,256,511,511))
        img6.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_6.tiff")

        img7=img.crop((512,256,767,511))
        img7.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_7.tiff")

        img8=img.crop((768,256,1023,511))
        img8.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_8.tiff")


        img9=img.crop((0,512,255,767))
        img9.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_9.tiff")

        img10=img.crop((256,512,511,767))
        img10.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_10.tiff")

        img11=img.crop((512,512,767,767))
        img11.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_11.tiff")

        img12=img.crop((768,512,1023,767))
        img12.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_12.tiff")



        img13=img.crop((0,768,255,1023))
        img13.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_13.tiff")

        img14=img.crop((256,768,511,1023))
        img14.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_14.tiff")

        img15=img.crop((512,768,767,1023))
        img15.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_15.tiff")

        img16=img.crop((768,768,1023,1023))
        img16.save("/lfs/Nevils/files_256/masks/"+name.strip(".tiff")+"_16.tiff")

# %%
for name in os.listdir("/data/Ro_ImageData/Low SN ratio ceramic images"):
    if name.endswith(".tiff"):
        img=Image.open("/data/Ro_ImageData/Low SN ratio ceramic images/"+name)

        img1=img.crop((0,0,255,255))
        img1.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_1.tiff")

        img2=img.crop((256,0,511,255))
        img2.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_2.tiff")

        img3=img.crop((512,0,767,255))
        img3.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_3.tiff")

        img4=img.crop((768,0,1023,255))
        img4.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_4.tiff")



        img5=img.crop((0,256,255,511))
        img5.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_5.tiff")

        img6=img.crop((256,256,511,511))
        img6.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_6.tiff")

        img7=img.crop((512,256,767,511))
        img7.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_7.tiff")

        img8=img.crop((768,256,1023,511))
        img8.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_8.tiff")


        img9=img.crop((0,512,255,767))
        img9.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_9.tiff")

        img10=img.crop((256,512,511,767))
        img10.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_10.tiff")

        img11=img.crop((512,512,767,767))
        img11.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_11.tiff")

        img12=img.crop((768,512,1023,767))
        img12.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_12.tiff")



        img13=img.crop((0,768,255,1023))
        img13.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_13.tiff")

        img14=img.crop((256,768,511,1023))
        img14.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_14.tiff")

        img15=img.crop((512,768,767,1023))
        img15.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_15.tiff")

        img16=img.crop((768,768,1023,1023))
        img16.save("/lfs/Nevils/files_256/real_lowSN/"+name.strip(".tiff")+"_16.tiff")
